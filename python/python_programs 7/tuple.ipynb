# %%
t=(1,2,2,2,3)

print(t.count(2))
# Out:
# 3

# %%
t=(10,20,30)

print(t.index(20))
# Out:
# 1

# %%
t=(4,7,2)

print(len(t))
print(max(t))
print(min(t))
print(sum(t))
print(sorted(t))
# Out:
# 3
# 7
# 2
# 13
# [2, 4, 7]

# %%
print(t[1])
print(t[-1])
# Out:
# 7
# 2

# %%
# ocurrence of an element

# max element

# slice a tuple
