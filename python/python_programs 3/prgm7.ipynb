# %% [markdown]
# 7. Take an amount in pounds and convert it to pence.

# %% [markdown]
# Create class and methods

# %%
class Conversion:
    def accept(self):
        self.pounds = int(input("Enter amount:"))
        
    def calculate(self):
        return pounds * 100

    def display(self):
        pence = self.calculate()
        print(f"Conversion = {pence}")

# %% [markdown]
# Create object

# %%
n_obj = Conversion()

# %%
n_obj.accept()
# Out:
# Enter amount: 100

# %%
n_obj.display()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 n_obj.display()
#
# Cell In[8], line 9, in Conversion.display(self)
#       8 def display(self):
# ----> 9     print(f"Conversion = {pence}")
#
# NameError: name 'pence' is not defined
