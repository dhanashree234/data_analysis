# %%
price = float(input("Enter price : "))
# Out:
# Enter price : 100

# %%
print(f"Product price = {price} and type of price : {type(price)}")
# Out:
# Product price = 100.0 and type of price : <class 'float'>
