# %%
sub1 = input("Enter subject 1: ")
m1 = int(input("Enter marks for subject 1: "))

sub2 = input("Enter subject 2: ")
m2 = int(input("Enter marks for subject 1: "))

sub3 = input("Enter subject 3: ")
m3 = int(input("Enter marks for subject 1: "))

sub4 = input("Enter subject 4: ")
m4 = int(input("Enter marks for subject 1: "))

sub5 = input("Enter subject 5: ")
m5 = int(input("Enter marks for subject 1: "))

total = m1+m2+m3+m4+m5
per = total/5
# Out:
# Enter subject 1: ai
# Enter marks for subject 1: 100
# Enter subject 2: ml
# Enter marks for subject 1: 90
# Enter subject 3: python
# Enter marks for subject 1: 95
# Enter subject 4: java
# Enter marks for subject 1: 100
# Enter subject 5: php
# Enter marks for subject 1: 100

# %%
print(f"Total = {total} \nPer = {per}")
# Out:
# Total = 485
# Per = 97.0
