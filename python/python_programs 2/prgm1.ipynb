# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Print name, age and country. Accept the input from user.

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: qwe

# %%
print("Name:", name)
# Out:
# Name: qwe

# %%
age = int(input("Enter age: "))
# Out:
# Enter age: 20

# %%
print("Age: ", age)
# Out:
# Age:  20

# %%
country = str(input("Enter country: "))
# Out:
# Enter country: uk

# %%
print("Country: ", country)
# Out:
# Country:  uk
