# %%
n1 = int(input("Enter number 1: "))
# Out:
# Enter number 1: 1

# %%
n2 = int(input("Enter number 2: "))
# Out:
# Enter number 2: 2

# %%
print(f"Number 1 = {n1} and Number 2 = {n2}")
# Out:
# Number 1 = 1 and Number 2 = 2
