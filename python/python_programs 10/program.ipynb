# %% [markdown]
# modules -
# math
# random
# os
# datetime
# time
# calendar
# statistics
# sys

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
print(math.factorial(5))
# Out:
# 120

# %%
import math
import random

print(math.sqrt(49))
print(random.randint(1,10))
# Out:
# 7.0
# 6

# %%
# alias
# import module_name as alias_name

# %%
# find area of circle
import math
r = 5
area = math.pi * r * r

print(area)
# Out:
# 78.53981633974483

# %%
import random
print(random.randint(1,10))
# Out:
# 8

# %%
import random
colors = ["red","yellow","green","blue"]
print(random.choice(colors))
# Out:
# blue

# %%
import random
numbers = [10,22,3,4,50]
random.shuffle(numbers)
print(numbers)
# Out:
# [10, 4, 50, 3, 22]

# %%
import time
print("start")
time.sleep(3)
print("end")
# Out:
# start
# end

# %%
import datetime
print(datetime.date.today())
# Out:
# 2026-07-22

# %%
# know current working directory, create folder, files
import os
print(os.getcwd())
# Out:
# e:\python\python_programs 10

# %%
import os 
os.mkdir("pythn")

# %%
os.rename("pythn", "sub")

# %%
print(os.listdir())
# Out:
# ['prgms_list.txt', 'program.ipynb', 'sub']

# %%
# system module
import sys
# sys.version
print(sys.version)
# Out:
# 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]

# %% [markdown]
# packages - collection of python modules organized inside a folder

# %%
# calculator_package
# │
# ├── __init__.py
# ├── arithmetic.py
# ├── geometry.py
# └── conversion.py
