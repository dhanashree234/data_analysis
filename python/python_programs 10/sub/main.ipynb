# %%
import cal
print(cal.add(1,2))
print(cal.mul(1,2))
print(cal.div(2,1))
# Out:
# 3
# 2
# 2.0

# %%
from cal import add # to import 
print(add(1,2))
# Out:
# 3

# %%
import cal as c
print(c.sub(2,1))
# Out:
# 1
